# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from countryinfo import CountryInfo

import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %matplotlib inline

# %%
cases = pd.read_csv('data/confirm.csv')
recover = pd.read_csv('data/recover.csv')
deaths = pd.read_csv('data/death.csv')

# %%
display(cases.head(), recover.head(), deaths.head())
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/27/20  4/28/20  4/29/20  4/30/20  5/1/20  \
# 0        0        0        0  ...     1703     1828     1939     2171    2335
# 1        0        0        0  ...      736      750      766      773     782
# 2        0        0        0  ...     3517     3649     3848     4006    4154
# 3        0        0        0  ...      743      743      743      745     745
# 4        0        0        0  ...       27       27       27       27      30
#
# ...

# %%
region = {}
subregion = {}

fails = []

regions = sorted(deaths['Country/Region'].unique())
for r in regions:
  try:
    country = CountryInfo(r)
    region[r] = country.region()
    subregion[r] = country.subregion()
  except:
    fails.append(r)
    print('No data for', r)
# Out:
# No data for Andorra
# No data for Bahamas
# No data for Burma
# No data for Cabo Verde
# No data for Congo (Brazzaville)
# No data for Congo (Kinshasa)
# No data for Cote d'Ivoire
# No data for Czechia
# No data for Diamond Princess
# No data for Eswatini
# No data for Gambia
# No data for Holy See
# No data for Korea, South
# No data for Kosovo
# No data for MS Zaandam
# No data for Montenegro
# No data for North Macedonia
# No data for Sao Tome and Principe
# No data for Serbia
# No data for Taiwan*
# No data for Timor-Leste
# No data for US
# No data for West Bank and Gaza

# %%
region['Cabo Verde'] = 'Africa'
region['Comoros (the)'] = 'Africa'
region['Congo (Brazzaville)'] = 'Africa'
region['Congo (Kinshasa)'] = 'Africa'
region["Cote d'Ivoire"] = 'Africa'
region['Eswatini'] = 'Africa'
region['Gambia'] = 'Africa'
region['Sao Tome and Principe'] = 'Africa'
region['Sudan (the)'] = 'Africa'


subregion['Cabo Verde'] = 'Western Africa'
subregion['Comoros (the)'] = 'Southern Africa'
subregion['Congo (Brazzaville)'] = 'Middle Africa'
subregion['Congo (Kinshasa)'] = 'Middle Africa'
subregion["Cote d'Ivoire"] = 'Western Africa'
subregion['Eswatini'] = 'Southern Africa'
subregion['Gambia'] = 'Western Africa'
subregion['Sao Tome and Principe'] = 'Middle Africa'
subregion['Sudan (the)'] = 'Eastern Africa'

# %%
def addColumns(df, region=region, subregion=subregion):
    # Adding in population as a column
    df['Region'] = df['Country/Region'].map(region)
    df['Subregion'] = df['Country/Region'].map(subregion)
    return df

# %%
cases = addColumns(cases)
recover = addColumns(recover)
deaths = addColumns(deaths)

# %%
# Re-arrange the data
cols = list(cases.columns)
cases = cases[cols[:4]+['Region','Subregion']+cols[4:-2]] # Better ordering
recover = recover[cols[:4]+['Region','Subregion']+cols[4:-2]] # Better ordering
deaths = deaths[cols[:4]+['Region','Subregion']+cols[4:-2]] # Better ordering

# %%
display(cases.head(), recover.head(), deaths.head())
# Out:
#   Province/State Country/Region      Lat     Long  Region        Subregion  \
# 0            NaN    Afghanistan  33.0000  65.0000    Asia    Southern Asia
# 1            NaN        Albania  41.1533  20.1683  Europe  Southern Europe
# 2            NaN        Algeria  28.0339   1.6596  Africa  Northern Africa
# 3            NaN        Andorra  42.5063   1.5218     NaN              NaN
# 4            NaN         Angola -11.2027  17.8739  Africa    Middle Africa
#
#    1/22/20  1/23/20  1/24/20  1/25/20  ...  4/27/20  4/28/20  4/29/20  \
# 0        0        0        0        0  ...     1703     1828     1939
# 1        0        0        0        0  ...      736      750      766
# 2        0        0        0        0  ...     3517     3649     3848
# 3        0        0        0        0  ...      743      743      743
# 4        0        0        0        0  ...       27       27       27
#
#    4/30/20  5/1/20  5/2/20  5/3/20  5/4/20  5/5/20  5/6/20
# ...

# %%
cases_africa = cases[cases['Region']=='Africa']
recover_africa = recover[recover['Region']=='Africa']
deaths_africa = deaths[deaths['Region']=='Africa']

# %%
cases_africa['daily'] = cases_africa.iloc[:,-1] - cases_africa.iloc[:,-2]
recover_africa['daily'] = recover_africa.iloc[:,-1] - recover_africa.iloc[:,-2]
deaths_africa['daily'] = deaths_africa.iloc[:,-1] - deaths_africa.iloc[:,-2]
# Out:
# /home/igori/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/igori/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/igori/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
display(cases_africa.head(), recover_africa.head(), deaths_africa.head())
# Out:
#    Province/State Country/Region      Lat     Long  Region        Subregion  \
# 2             NaN        Algeria  28.0339   1.6596  Africa  Northern Africa
# 4             NaN         Angola -11.2027  17.8739  Africa    Middle Africa
# 24            NaN          Benin   9.3077   2.3158  Africa   Western Africa
# 31            NaN   Burkina Faso  12.2383  -1.5616  Africa   Western Africa
# 32            NaN     Cabo Verde  16.5388 -23.0418  Africa   Western Africa
#
#     1/22/20  1/23/20  1/24/20  1/25/20  ...  4/28/20  4/29/20  4/30/20  \
# 2         0        0        0        0  ...     3649     3848     4006
# 4         0        0        0        0  ...       27       27       27
# 24        0        0        0        0  ...       64       64       64
# 31        0        0        0        0  ...      638      641      645
# 32        0        0        0        0  ...      114      114      121
#
#     5/1/20  5/2/20  5/3/20  5/4/20  5/5/20  5/6/20  daily
# ...

# %%
cols = list(cases_africa.columns)

cases_africa = cases_africa[['Country/Region' , 'Region' , 'Subregion'] + cols[-2:]]
recover_africa = recover_africa[['Country/Region' , 'Region' , 'Subregion'] + cols[-2:]]
deaths_africa = deaths_africa[['Country/Region' , 'Region' , 'Subregion'] + cols[-2:]]

# %%
display(cases_africa.head(), recover_africa.head(), deaths_africa.head())
# Out:
#    Country/Region  Region        Subregion  5/6/20  daily
# 2         Algeria  Africa  Northern Africa    4997    159
# 4          Angola  Africa    Middle Africa      36      0
# 24          Benin  Africa   Western Africa      96      0
# 31   Burkina Faso  Africa   Western Africa     729     41
# 32     Cabo Verde  Africa   Western Africa     191      5
#    Country/Region  Region        Subregion  5/6/20  daily
# 2         Algeria  Africa  Northern Africa    2197    130
# 4          Angola  Africa    Middle Africa      11      0
# 25          Benin  Africa   Western Africa      50      0
# 32   Burkina Faso  Africa   Western Africa     555      7
# 33     Cabo Verde  Africa   Western Africa      38      1
#    Country/Region  Region        Subregion  5/6/20  daily
# 2         Algeria  Africa  Northern Africa     476      6
# 4          Angola  Africa    Middle Africa       2      0
# 24          Benin  Africa   Western Africa       2      0
# ...

# %%
cases_africa_sorted = cases_africa.sort_values(by='daily', ascending=False)
recover_africa_sorted = recover_africa.sort_values(by='daily', ascending=False)
deaths_africa_sorted = deaths_africa.sort_values(by='daily', ascending=False)

# %%
display(cases_africa_sorted.head(), recover_africa_sorted.head(), deaths_africa_sorted.head())
# Out:
#     Country/Region  Region        Subregion  5/6/20  daily
# 98           Egypt  Africa  Northern Africa    7588    387
# 121          Ghana  Africa   Western Africa    3091    372
# 200   South Africa  Africa  Southern Africa    7808    236
# 173        Nigeria  Africa   Western Africa    3145    195
# 163        Morocco  Africa  Northern Africa    5408    189
#     Country/Region  Region        Subregion  5/6/20  daily
# 198   South Africa  Africa  Southern Africa    3153    407
# 159        Morocco  Africa  Northern Africa    2017    179
# 2          Algeria  Africa  Northern Africa    2197    130
# 212        Tunisia  Africa  Northern Africa     591    109
# 117         Guinea  Africa   Western Africa     597     99
#     Country/Region  Region        Subregion  5/6/20  daily
# 34        Cameroon  Africa    Middle Africa     108     44
# 98           Egypt  Africa  Northern Africa     469     17
# 2          Algeria  Africa  Northern Africa     476      6
# ...

# %%
cases_africa_sorted.head().to_csv('top_cases.csv')
recover_africa_sorted.head().to_csv('top_recover.csv')
deaths_africa_sorted.head().to_csv('top_deaths.csv')

# %%
cases_africa_sorted_sum = cases_africa_sorted.groupby('Region').sum()
recover_africa_sorted_sum = recover_africa_sorted.groupby('Region').sum()
deaths_africa_sorted_sum = deaths_africa_sorted.groupby('Region').sum()

# %%
display(cases_africa_sorted_sum.head(), recover_africa_sorted_sum.head(), deaths_africa_sorted_sum.head())
# Out:
#         5/6/20  daily
# Region
# Africa   51549   2546
#         5/6/20  daily
# Region
# Africa   17634   1309
#         5/6/20  daily
# Region
# Africa    2006     98

# %%
cols = list(cases.columns)
Africa_cases = cases[cases['Region']=='Africa']
Africa_recover = recover[recover['Region']=='Africa']
Africa_deaths = deaths[deaths['Region']=='Africa']
Africa_cases[['Country/Region'] + cols[4:6] + cols[6:]]
# Out:
#                Country/Region  Region        Subregion  1/22/20  1/23/20  \
# 2                     Algeria  Africa  Northern Africa        0        0
# 4                      Angola  Africa    Middle Africa        0        0
# 24                      Benin  Africa   Western Africa        0        0
# 31               Burkina Faso  Africa   Western Africa        0        0
# 32                 Cabo Verde  Africa   Western Africa        0        0
# 34                   Cameroon  Africa    Middle Africa        0        0
# 46   Central African Republic  Africa    Middle Africa        0        0
# 47                       Chad  Africa    Middle Africa        0        0
# 83        Congo (Brazzaville)  Africa    Middle Africa        0        0
# 84           Congo (Kinshasa)  Africa    Middle Africa        0        0
# 86              Cote d'Ivoire  Africa   Western Africa        0        0
# 95                   Djibouti  Africa   Eastern Africa        0        0
# ...

# %%
pd.DataFrame(Africa_cases[['Country/Region'] + cols[4:6] + cols[6:]].groupby('Region').sum().T)
# Out:
# Region   Africa
# 1/22/20       0
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0
# ...         ...
# 5/2/20    42772
# 5/3/20    44307
# 5/4/20    46965
# 5/5/20    49003
# 5/6/20    51549
#
# [106 rows x 1 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=Africa_cases[cols[4:]].groupby('Region').sum().T.index,
    y=Africa_cases[cols[4:]].groupby('Region').sum().T.Africa,
    name='Cases',
    marker_color='orange'
))

fig.add_trace(go.Scatter(
    x=Africa_cases[cols[4:]].groupby('Region').sum().T.index,
    y=Africa_recover[cols[4:]].groupby('Region').sum().T.Africa,
    name='Recover',
    marker_color='green'
))

fig.add_trace(go.Scatter(
    x=Africa_cases[cols[4:]].groupby('Region').sum().T.index,
    y=Africa_deaths[cols[4:]].groupby('Region').sum().T.Africa,
    name='Deaths',
    marker_color='red'
))

fig.update_layout(title = 'Africa')
fig.show()

# %%
pd.DataFrame(Africa_cases[['Country/Region'] + cols[4:6] + cols[6:]].groupby('Region').sum().T.Africa)
# Out:
#          Africa
# 1/22/20       0
# 1/23/20       0
# 1/24/20       0
# 1/25/20       0
# 1/26/20       0
# ...         ...
# 5/2/20    42772
# 5/3/20    44307
# 5/4/20    46965
# 5/5/20    49003
# 5/6/20    51549
#
# [106 rows x 1 columns]

# %%
Africa_cases[['Country/Region'] + cols[4:6] + cols[6:]].groupby('Region').sum().T.Africa_cases()
Africa_recover[['Country/Region'] + cols[4:6] + cols[6:]].groupby('Region').sum().T.plot()
Africa_deaths[['Country/Region'] + cols[4:6] + cols[6:]].groupby('Region').sum().T.plot()

# %%
cols = list(cases.columns)
dateArr = cols[-1].split('/')
date = '_'.join([dateArr[1], dateArr[0], dateArr[2]])
dateName = 'virdash_'+date+'20.xlsx'

# %%
cols = list(cases.columns)

writer = pd.ExcelWriter(dateName, engine='xlsxwriter')

# %%
# Write each dataframe to a different worksheet.
cases_africa_sorted_sum.to_excel(writer, sheet_name='Total_cases')
recover_africa_sorted_sum.to_excel(writer, sheet_name='Total_recover')
deaths_africa_sorted_sum.to_excel(writer, sheet_name='Total_deaths')

cases_africa_sorted.to_excel(writer, sheet_name='Top_cases')
recover_africa_sorted.to_excel(writer, sheet_name='Top_recover')
deaths_africa_sorted.to_excel(writer, sheet_name='Top_deaths')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
